# %% [markdown]
# # Import Library

# %%
from historyManagement import *

# suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # For Regression

# %%
show_model_history(model_type='regression')
# Out:
# 📊 REGRESSION Model Performance History
# ...
#                    Model         Scaler         Target  Features          MSE        MAE       RMSE       R²
#            Random Forest   RobustScaler    SolarEnergy        27     0.002912   0.030780   0.053960 0.997610
#            Random Forest StandardScaler    SolarEnergy        27     0.002914   0.030797   0.053981 0.997608
#            Random Forest   MinMaxScaler    SolarEnergy        27     0.002916   0.030813   0.054004 0.997606
#      Random Forest Tuned StandardScaler    SolarEnergy        27     0.002919   0.030990   0.054030 0.997604
#      Random Forest Tuned   RobustScaler    SolarEnergy        27     0.002929   0.030948   0.054123 0.997596
#      Random Forest Tuned   MinMaxScaler    SolarEnergy        27     0.002935   0.030988   0.054176 0.997591
#  Gradient Boosting Tuned   RobustScaler    SolarEnergy        22     0.003036   0.032194   0.055096 0.997509
# ...

# %% [markdown]
# # For Classification

# %%
show_model_history(model_type='classification')
# Out:
# 📊 CLASSIFICATION Model Performance History
# ...
#                             Model         Scaler     Target  Features Accuracy Precision   Recall F1-Score
#            Gradient Boosting Grid   MinMaxScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#            Gradient Boosting Grid StandardScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#            Gradient Boosting Grid   RobustScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#                Random Forest Grid   MinMaxScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#                Random Forest Grid StandardScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#                Random Forest Grid   RobustScaler Conditions        23 0.996580  0.996597 0.996580 0.996575
#                 Gradient Boosting   MinMaxScaler Conditions        23 0.996238  0.996251 0.996238 0.996233
# ...
